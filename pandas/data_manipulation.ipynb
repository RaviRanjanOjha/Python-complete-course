# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#       Project ID Customer Name Customer Group Description Delivery IBU ID  \
# 0    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 1    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 2    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 3    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 4    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# ..           ...           ...                        ...             ...
# 97   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 98   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 99   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 100  Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 101  Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
#
#     Delivery IBG ID Proj Pricing Model Fiscal Month  Fiscal Year  \
# ...

# %%
df.describe()
# Out:
#        Fiscal Year
# count   102.000000
# mean   2024.029412
# std       0.169792
# min    2024.000000
# 25%    2024.000000
# 50%    2024.000000
# 75%    2024.000000
# max    2025.000000

# %%
df.dtypes
# Out:
# Project ID                    object
# Customer Name                 object
# Customer Group Description    object
# Delivery IBU ID               object
# Delivery IBG ID               object
# Proj Pricing Model            object
# Fiscal Month                  object
# Fiscal Year                    int64
# Vertical                      object
# Sales SBU ID                  object
# Sales IBG ID                  object
# Contract Sub Type             object
# Quarter                       object
#  Revenue Offshore             object
#  Revenue Onsite               object
#  Revenue Bought Out           object
#  Revenue Total                object
# dtype: object

# %%
df.isnull()
# Out:
#      Project ID  Customer Name  Customer Group Description  Delivery IBU ID  \
# 0         False          False                       False            False
# 1         False          False                       False            False
# 2         False          False                       False            False
# 3         False          False                       False            False
# 4         False          False                       False            False
# ..          ...            ...                         ...              ...
# 97        False          False                       False            False
# 98        False          False                       False            False
# 99        False          False                       False            False
# 100       False          False                       False            False
# 101       False          False                       False            False
#
# ...

# %%
df.isnull().any()
# Out:
# Project ID                    False
# Customer Name                 False
# Customer Group Description    False
# Delivery IBU ID               False
# Delivery IBG ID               False
# Proj Pricing Model             True
# Fiscal Month                  False
# Fiscal Year                   False
# Vertical                      False
# Sales SBU ID                  False
# Sales IBG ID                  False
# Contract Sub Type              True
# Quarter                       False
#  Revenue Offshore             False
#  Revenue Onsite               False
#  Revenue Bought Out           False
#  Revenue Total                False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Project ID                     0
# Customer Name                  0
# Customer Group Description     0
# Delivery IBU ID                0
# Delivery IBG ID                0
# Proj Pricing Model             6
# Fiscal Month                   0
# Fiscal Year                    0
# Vertical                       0
# Sales SBU ID                   0
# Sales IBG ID                   0
# Contract Sub Type             16
# Quarter                        0
#  Revenue Offshore              0
#  Revenue Onsite                0
#  Revenue Bought Out            0
#  Revenue Total                 0
# dtype: int64

# %%
df.fillna(0)
# Out:
#       Project ID Customer Name Customer Group Description Delivery IBU ID  \
# 0    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 1    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 2    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 3    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 4    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# ..           ...           ...                        ...             ...
# 97   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 98   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 99   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 100  Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 101  Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
#
#     Delivery IBG ID Proj Pricing Model Fiscal Month  Fiscal Year  \
# ...

# %%
df.rename(columns={'Revenue Offshore': 'Revenue_Offshore'})
# Out:
#       Project ID Customer Name Customer Group Description Delivery IBU ID  \
# 0    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 1    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 2    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 3    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 4    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# ..           ...           ...                        ...             ...
# 97   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 98   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 99   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 100  Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 101  Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
#
#     Delivery IBG ID Proj Pricing Model Fiscal Month  Fiscal Year  \
# ...

# %%
df
# Out:
#       Project ID Customer Name Customer Group Description Delivery IBU ID  \
# 0    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 1    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 2    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 3    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# 4    Y.IN2301702    Customer 1           Customer Group 1      DEA-D-4001
# ..           ...           ...                        ...             ...
# 97   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 98   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 99   Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 100  Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
# 101  Z.IN2301551  Customer 315         Customer Group 234      DEA-N-4002
#
#     Delivery IBG ID Proj Pricing Model Fiscal Month  Fiscal Year  \
# ...

# %%
##change datatype of a column
## df['Revenue Offshore'] = pd.to_numeric(df['Revenue Offshore'], errors='coerce').fillna(0).astype(float)
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Python-complete-course/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Revenue Offshore'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 2
# ...

# %%
## apply function to a column
df['New_Revenue_Offshore'] = df['Revenue Offshore'].apply(lambda x: x*12)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Python-complete-course/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Revenue Offshore'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 2
# ...

# %%
## data aggregation and grouping
groupedby_mean = pd.groupby('Country')['Revenue Total'].mean()
print(groupedby_mean)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 2
#       1 ## data aggregation and grouping
# ----> 2 groupedby_mean = pd.groupby('Country')['Revenue Total'].mean()
#       3 print(groupedby_mean)
#
# AttributeError: module 'pandas' has no attribute 'groupby'

# %%
## merging and joining dataframes
df1 = pd.DataFrame({'key': ['A', 'B', 'C'], 'value1': [1, 2, 3]})
df2 = pd.DataFrame({'key': ['A', 'B', 'D'], 'value2': [4, 5, 6]})
df1.merge(df2, on='key', how='inner')
# Out:
#   key  value1  value2
# 0   A       1       4
# 1   B       2       5

# %%
df1.merge(df2, on='key', how='outer')
# Out:
#   key  value1  value2
# 0   A     1.0     4.0
# 1   B     2.0     5.0
# 2   C     3.0     NaN
# 3   D     NaN     6.0
